# %%
import cfbd
import datetime
import numpy as np
import pandas as pd
from config import credentials

# %%
# configure API key
configuration = cfbd.Configuration()
configuration.api_key['Authorization'] = credentials.API_KEY
configuration.api_key_prefix['Authorization'] = 'Bearer'

# instantiate a games API instance
api_config = cfbd.ApiClient(configuration)
games_api = cfbd.GamesApi(cfbd.ApiClient(configuration))

# %%
def date_sort(game):
    game_date = datetime.datetime.strptime(game['start_date'], "%Y-%m-%dT%H:%M:%S.000Z")
    return game_date

def elo_sort(team):
    return team['elo']

def get_expected_score(rating, opp_rating):
    exp = (opp_rating - rating) / 400
    return 1 / (1 + 10**exp)

def get_new_elos(home_rating, away_rating, margin):
    k = 25
    
    # score of 0.5 for a tie
    home_score = 0.5
    if margin > 0:
        # score of 1 for a win
        home_score = 1
    elif margin < 0:
        #score of 0 for a loss
        home_score = 0
    
    # get expected home score
    expected_home_score = get_expected_score(home_rating, away_rating)
    # multiply difference of actual and expected score by k value and adjust home rating
    new_home_score = home_rating + k * (home_score - expected_home_score)
        
    # repeat these steps for the away team
    # away score is inverse of home score
    away_score = 1 - home_score
    expected_away_score = get_expected_score(away_rating, home_rating)
    new_away_score = away_rating + k * (away_score - expected_away_score)
    
    # return a tuple
    return (round(new_home_score), round(new_away_score))

# %%
print(get_expected_score(1500, 1500))
print(get_expected_score(1400, 1500))
print(get_expected_score(2000, 1500))
# Out:
# 0.5
# 0.35993500019711494
# 0.9467597847979775

# %%
games = []

for year in range(2000, 2022):
    response = games_api.get_games(year=year)
    games = [*games, *response]
    
games = [dict(
            start_date=g.start_date,
            home_team=g.home_team,
            home_conference=g.home_conference,
            home_points=g.home_points,
            away_team=g.away_team,
            away_conference=g.away_conference,
            away_points=g.away_points
            ) for g in games if g.home_points is not None and g.away_points is not None]
games.sort(key=date_sort)

# %%
# dict object to hold current Elo rating for each team
teams = dict()

# loop through games in order
for game in games:
    
    # get current rating for home team
    if game['home_team'] in teams:
        home_elo = teams[game['home_team']]
    elif game['home_conference'] is not None:
        # if no rating, set initial rating to 1500 for FBS teams
        home_elo = 1500
    else:
        # otherwise, set initial rating to 1200 for non-FBS teams
        home_elo = 1200

    # get current rating for away team
    if game['away_team'] in teams:
        away_elo = teams[game['away_team']]
    elif game['away_conference'] is not None:
        # if no rating, set initial rating to 1500 for FBS teams
        away_elo = 1500
    else:
        # otherwise, set initial rating to 1200 for non-FBS teams
        away_elo = 1200
        
    # calculate score margin from game
    margin = game['home_points'] - game['away_points']
    
    # get new elo ratings
    new_elos = get_new_elos(home_elo, away_elo, margin)
    
    # set pregame elos on game dict
    game['pregame_home_elo'] = home_elo
    game['pregame_away_elo'] = away_elo
    
    # set postgame elos on game dict
    game['postgame_home_elo'] = new_elos[0]
    game['postgame_away_elo'] = new_elos[1]
    
    # set current elo values in teams dict
    teams[game['home_team']] = new_elos[0]
    teams[game['away_team']] = new_elos[1]

# %%
end_elos = [dict(team=key, elo=teams[key]) for key in teams]
end_elos.sort(key=elo_sort, reverse=True)

end_elos
# Out:
# [{'team': 'Alabama', 'elo': 2095},
#  {'team': 'Ohio State', 'elo': 2025},
#  {'team': 'St Francis (PA)', 'elo': 1309},
#  {'team': 'Alderson-Broaddus', 'elo': 1304},
#  {'team': 'California (PA)', 'elo': 1303},
#  {'team': 'Franklin Pierce', 'elo': 1303},
#  {'team': 'Augustana (SD)', 'elo': 1302},
#  {'team': 'Minnesota-Duluth', 'elo': 1302},
#  {'team': 'Northern Arizona', 'elo': 1301},
#  {'team': 'Davidson', 'elo': 1299},
#  {'team': 'Sioux Falls', 'elo': 1299},
#  {'team': 'New Haven', 'elo': 1298},
#  {'team': 'Stetson', 'elo': 1298},
#  {'team': 'Lenoir-Rhyne', 'elo': 1295},
#  {'team': 'Long Island University', 'elo': 1293},
#  {'team': 'Pittsburg State', 'elo': 1292},
#  {'team': 'Angelo State', 'elo': 1291},
#  {'team': 'Truman State', 'elo': 1291},
#  {'team': 'Lindenwood', 'elo': 1291},
#  {'team': 'Limestone', 'elo': 1290},
#  {'team': 'Hampton', 'elo': 1288},
#  {'team': 'Newberry', 'elo': 1286},
#  {'team': 'Nebraska-Kearney', 'elo': 1286},
#  {'team': 'Ouachita Baptist', 'elo': 1284},
#  {'team': 'South Alabama', 'elo': 1284},
#  {'team': 'Jacksonville', 'elo': 1282},
#  {'team': 'Henderson State', 'elo': 1281},
#  {'team': 'Slippery Rock', 'elo': 1281},
#  {'team': 'UNLV', 'elo': 1280},
#  {'team': 'Abilene Christian', 'elo': 1280},
#  {'team': 'Alabama A&M', 'elo': 1279},
#  {'team': 'Idaho', 'elo': 1278},
#  {'team': 'Wingate', 'elo': 1278},
#  {'team': 'Bowie State', 'elo': 1277},
#  {'team': 'West Georgia', 'elo': 1276},
#  {'team': 'Marist', 'elo': 1275},
#  {'team': 'Iona', 'elo': 1275},
#  {'team': 'New Mexico', 'elo': 1273},
#  {'team': 'Bentley', 'elo': 1273},
#  {'team': 'Charleston (WV)', 'elo': 1272},
#  {'team': 'Austin Peay', 'elo': 1271},
#  {'team': 'Western Illinois', 'elo': 1266},
#  {'team': 'Southeast Missouri State', 'elo': 1265},
#  {'team': "St. Peter's", 'elo': 1265},
#  {'team': 'Cornell', 'elo': 1265},
#  {'team': 'Stonehill', 'elo': 1264},
#  {'team': 'Louisiana Monroe', 'elo': 1263},
#  {'team': 'Central Washington', 'elo': 1263},
#  {'team': 'Rice', 'elo': 1261},
#  {'team': 'College of New Jersey', 'elo': 1261},
#  {'team': 'Wayne State (NE)', 'elo': 1260},
#  {'team': 'Robert Morris', 'elo': 1260},
#  {'team': 'UNC Pembroke', 'elo': 1260},
#  {'team': 'Florida International', 'elo': 1259},
#  {'team': 'Colorado Mesa', 'elo': 1259},
#  {'team': 'Montclair State', 'elo': 1258},
#  {'team': 'Morehead State', 'elo': 1257},
#  {'team': 'Texas A&M-Commerce', 'elo': 1257},
#  {'team': 'Bowling Green', 'elo': 1255},
#  {'team': 'Midwestern State', 'elo': 1253},
#  {'team': 'Tarleton State', 'elo': 1252},
#  {'team': 'Oklahoma Baptist', 'elo': 1251},
#  {'team': 'Portland State', 'elo': 1250},
#  {'team': 'Birmingham-Southern', 'elo': 1250},
#  {'team': 'Norfolk State', 'elo': 1249},
#  {'team': 'Gannon', 'elo': 1249},
#  {'team': 'North Alabama', 'elo': 1249},
#  {'team': 'Winston-Salem', 'elo': 1249},
#  {'team': "St. Joseph's (IN)", 'elo': 1248},
#  {'team': 'Rhodes', 'elo': 1246},
#  {'team': 'Ursinus', 'elo': 1243},
#  {'team': 'Western Connecticut State', 'elo': 1242},
#  {'team': 'Indianapolis', 'elo': 1242},
#  {'team': 'Fayetteville State', 'elo': 1241},
#  {'team': 'Wesley College', 'elo': 1241},
#  {'team': 'Florida Tech', 'elo': 1241},
#  {'team': 'Lafayette', 'elo': 1240},
#  {'team': 'East Central', 'elo': 1239},
#  {'team': 'Campbell', 'elo': 1239},
#  {'team': 'UTEP', 'elo': 1235},
#  {'team': 'Geneva College', 'elo': 1235},
#  {'team': 'Minnesota State', 'elo': 1235},
#  {'team': 'Emporia State', 'elo': 1235},
#  {'team': 'Assumption', 'elo': 1235},
#  {'team': 'Merrimack', 'elo': 1234},
#  {'team': 'Brown', 'elo': 1233},
#  {'team': 'Catawba', 'elo': 1233},
#  {'team': 'Northern Michigan', 'elo': 1231},
#  {'team': 'Grand View', 'elo': 1231},
#  {'team': 'Alabama State', 'elo': 1229},
#  {'team': 'Missouri S&T', 'elo': 1229},
#  {'team': 'Texas A&M-Kingsville', 'elo': 1228},
#  {'team': 'West Chester', 'elo': 1227},
#  {'team': 'Western Washington', 'elo': 1227},
#  {'team': 'Northeastern', 'elo': 1225},
#  {'team': 'Connecticut', 'elo': 1224},
#  {'team': 'Cal Poly', 'elo': 1222},
#  {'team': 'Tennessee State', 'elo': 1221},
#  {'team': 'Colorado State-Pueblo', 'elo': 1221},
#  {'team': 'Lawrence Tech', 'elo': 1221},
#  {'team': 'Northwestern State', 'elo': 1220},
#  {'team': 'Salisbury', 'elo': 1218},
#  {'team': 'Catholic University', 'elo': 1217},
#  {'team': 'Kentucky State', 'elo': 1217},
#  {'team': 'Texas State', 'elo': 1216},
#  {'team': 'Husson', 'elo': 1216},
#  {'team': 'Rowan', 'elo': 1215},
#  {'team': 'Delta State', 'elo': 1213},
#  {'team': 'Edinboro', 'elo': 1211},
#  {'team': 'Butler', 'elo': 1211},
#  {'team': 'Carthage', 'elo': 1211},
#  {'team': 'Western State', 'elo': 1210},
#  {'team': 'St. Francis (IN)', 'elo': 1210},
#  {'team': 'Cumberland College', 'elo': 1209},
#  {'team': 'Marian', 'elo': 1209},
#  {'team': 'Mercyhurst', 'elo': 1208},
#  {'team': 'Arkansas-Monticello', 'elo': 1207},
#  {'team': 'Virginia Union', 'elo': 1207},
#  {'team': 'Chadron State', 'elo': 1207},
#  {'team': 'St. Francis (IL)', 'elo': 1207},
#  {'team': 'West Alabama', 'elo': 1206},
#  {'team': 'Tusculum', 'elo': 1205},
#  {'team': 'West Liberty', 'elo': 1205},
#  {'team': 'Urbana', 'elo': 1204},
#  {'team': 'McMurry', 'elo': 1204},
#  {'team': 'Western Carolina', 'elo': 1203},
#  {'team': 'Murray State', 'elo': 1203},
#  {'team': 'Gardner-Webb', 'elo': 1202},
#  {'team': 'Lamar', 'elo': 1202},
#  {'team': 'Trinity International (IL)', 'elo': 1201},
#  {'team': 'Methodist', 'elo': 1201},
#  {'team': 'Indiana Wesleyan', 'elo': 1201},
#  {'team': 'WV State', 'elo': 1200},
#  {'team': 'Akron', 'elo': 1199},
#  {'team': 'Maryville TN', 'elo': 1199},
#  {'team': 'La Salle', 'elo': 1197},
#  {'team': 'Chapman', 'elo': 1197},
#  {'team': 'Mansfield', 'elo': 1197},
#  {'team': 'LIU Post', 'elo': 1196},
#  {'team': 'Albion', 'elo': 1196},
#  {'team': 'St. Ambrose', 'elo': 1196},
#  {'team': 'Wayland Baptist', 'elo': 1196},
#  {'team': 'Berry College', 'elo': 1196},
#  {'team': 'Carnegie Mellon', 'elo': 1196},
#  {'team': 'Southern Utah', 'elo': 1195},
#  {'team': 'Hartwick', 'elo': 1195},
#  {'team': 'Belhaven College', 'elo': 1195},
#  {'team': 'Bethel Col', 'elo': 1195},
#  {'team': 'Greensboro', 'elo': 1194},
#  {'team': 'MONTANASTN', 'elo': 1194},
#  {'team': 'New Mexico State', 'elo': 1193},
#  {'team': 'Miles', 'elo': 1193},
#  {'team': 'Central Missouri State', 'elo': 1193},
#  {'team': 'Salve Regina', 'elo': 1193},
#  {'team': 'Buffalo State', 'elo': 1192},
#  {'team': 'Kean', 'elo': 1192},
#  {'team': 'Kalamazoo', 'elo': 1192},
#  {'team': 'St. Cloud State', 'elo': 1192},
#  {'team': 'Bethany (KS)', 'elo': 1192},
#  {'team': 'Wisconsin-La Crosse', 'elo': 1191},
#  {'team': 'Apprentice School', 'elo': 1191},
#  {'team': 'Central Oklahoma', 'elo': 1191},
#  {'team': 'Concordia College (MI)', 'elo': 1191},
#  {'team': 'Wisconsin Lutheran', 'elo': 1190},
#  {'team': 'Bloomsburg', 'elo': 1190},
#  {'team': 'Arizona Christian', 'elo': 1190},
#  {'team': 'Franklin', 'elo': 1189},
#  {'team': 'MARIAN (IN', 'elo': 1189},
#  {'team': 'Lindsey Wilson', 'elo': 1188},
#  {'team': 'Georgetown (KY)', 'elo': 1187},
#  {'team': 'Wisconsin-Platteville', 'elo': 1187},
#  {'team': "St. Paul's College", 'elo': 1187},
#  {'team': 'Baker University', 'elo': 1187},
#  {'team': 'Willamette', 'elo': 1187},
#  {'team': 'Reinhardt', 'elo': 1187},
#  {'team': 'Arkansas Baptist', 'elo': 1187},
#  {'team': 'Menlo', 'elo': 1186},
#  {'team': 'Aurora', 'elo': 1186},
#  {'team': 'Faulkner', 'elo': 1186},
#  {'team': 'Humboldt State', 'elo': 1185},
#  {'team': 'SUNY Maritime', 'elo': 1185},
#  {'team': 'College of Faith - Charlotte', 'elo': 1185},
#  {'team': 'St. Andrews', 'elo': 1185},
#  {'team': 'Cal State Northridge', 'elo': 1184},
#  {'team': 'University of Faith', 'elo': 1184},
#  {'team': 'Mayville State', 'elo': 1184},
#  {'team': 'Delaware Valley', 'elo': 1183},
#  {'team': 'Southwestern College', 'elo': 1183},
#  {'team': 'Georgetown', 'elo': 1182},
#  {'team': 'Wittenberg', 'elo': 1182},
#  {'team': 'Culver-Stockton', 'elo': 1182},
#  {'team': 'Concordia (WI)', 'elo': 1181},
#  {'team': 'Tuskegee', 'elo': 1180},
#  {'team': 'Texas Wesleyan', 'elo': 1180},
#  {'team': 'Bucknell', 'elo': 1178},
#  {'team': 'VMI', 'elo': 1178},
#  {'team': 'Benedict College', 'elo': 1177},
#  {'team': 'Waldorf', 'elo': 1177},
#  {'team': 'Hanover', 'elo': 1176},
#  {'team': 'Southern Connecticut State', 'elo': 1176},
#  {'team': 'Shaw', 'elo': 1176},
#  {'team': 'Arkansas Tech', 'elo': 1176},
#  {'team': 'Evangel', 'elo': 1175},
#  {'team': 'Azusa Pacific', 'elo': 1173},
#  {'team': 'Southern Virginia', 'elo': 1173},
#  {'team': 'Missouri Baptist', 'elo': 1173},
#  {'team': 'College of Idaho', 'elo': 1173},
#  {'team': 'St. Xavier (IL)', 'elo': 1172},
#  {'team': 'Chowan', 'elo': 1172},
#  {'team': 'American International', 'elo': 1172},
#  {'team': 'Concord', 'elo': 1170},
#  {'team': 'St. Anselm', 'elo': 1170},
#  {'team': 'Mars Hill', 'elo': 1170},
#  {'team': 'Ave Maria', 'elo': 1169},
#  {'team': 'Lane', 'elo': 1168},
#  {'team': 'William Penn', 'elo': 1167},
#  {'team': 'Taylor', 'elo': 1167},
#  {'team': 'Eastern Oregon', 'elo': 1167},
#  {'team': 'Howard', 'elo': 1166},
#  {'team': 'Southern Arkansas', 'elo': 1166},
#  {'team': 'UVA-Wise', 'elo': 1166},
#  {'team': 'UMass', 'elo': 1165},
#  {'team': 'Cheyney', 'elo': 1165},
#  {'team': 'Minot State', 'elo': 1165},
#  {'team': 'UFTL', 'elo': 1165},
#  {'team': 'New Mexico Highlands', 'elo': 1164},
#  {'team': 'Iowa Wesleyan', 'elo': 1164},
#  {'team': 'Fort Valley State', 'elo': 1164},
#  {'team': 'Bluefield College', 'elo': 1164},
#  {'team': 'Lambuth', 'elo': 1163},
#  {'team': 'Eastern New Mexico', 'elo': 1163},
#  {'team': 'Webber International', 'elo': 1162},
#  {'team': 'OK Panhandle St', 'elo': 1161},
#  {'team': 'Stillman', 'elo': 1160},
#  {'team': 'North Greenville', 'elo': 1159},
#  {'team': 'Central Methodist', 'elo': 1158},
#  {'team': 'Savannah State', 'elo': 1157},
#  {'team': 'Pikeville', 'elo': 1153},
#  {'team': 'Southwest Baptist', 'elo': 1152},
#  {'team': 'West Virginia Tech', 'elo': 1150},
#  {'team': 'Northern Colorado', 'elo': 1149},
#  {'team': 'Carson-Newman', 'elo': 1149},
#  {'team': 'Valparaiso', 'elo': 1147},
#  {'team': 'Idaho State', 'elo': 1146},
#  {'team': 'Allen', 'elo': 1146},
#  {'team': 'Kentucky Christian', 'elo': 1146},
#  {'team': 'Bethel (TN)', 'elo': 1145},
#  {'team': 'Pace', 'elo': 1145},
#  {'team': 'Northeastern State', 'elo': 1145},
#  {'team': 'Virginia State', 'elo': 1143},
#  {'team': 'Shorter', 'elo': 1141},
#  {'team': 'Upper Iowa', 'elo': 1138},
#  {'team': 'Wagner', 'elo': 1136},
#  {'team': 'Morgan State', 'elo': 1131},
#  {'team': 'Warner', 'elo': 1129},
#  {'team': 'Lincoln University (CA)', 'elo': 1128},
#  {'team': 'Western Oregon', 'elo': 1127},
#  {'team': 'Elizabeth City State', 'elo': 1127},
#  {'team': 'Concordia (AL)', 'elo': 1126},
#  {'team': 'Montana-Western', 'elo': 1124},
#  {'team': 'Black Hills State', 'elo': 1124},
#  {'team': 'Point University', 'elo': 1124},
#  {'team': 'Tennessee Tech', 'elo': 1123},
#  {'team': 'Bacone College', 'elo': 1123},
#  {'team': 'Union College', 'elo': 1121},
#  {'team': 'Quincy', 'elo': 1120},
#  {'team': 'Glenville State', 'elo': 1119},
#  {'team': 'Morehouse', 'elo': 1118},
#  {'team': 'Delaware State', 'elo': 1117},
#  {'team': 'Northwestern Oklahoma State', 'elo': 1117},
#  {'team': 'Southern Oregon', 'elo': 1114},
#  {'team': 'Eastern Illinois', 'elo': 1108},
#  {'team': 'Lincoln (MO)', 'elo': 1105},
#  {'team': 'Arkansas-Pine Bluff', 'elo': 1103},
#  {'team': 'Cumberland', 'elo': 1101},
#  {'team': 'Langston', 'elo': 1101},
#  {'team': 'Brevard College', 'elo': 1096},
#  {'team': 'Southwestern Oklahoma', 'elo': 1094},
#  {'team': 'William Jewell College', 'elo': 1094},
#  {'team': "St. Augustine's", 'elo': 1093},
#  {'team': 'Presbyterian College', 'elo': 1092},
#  {'team': 'Lock Haven', 'elo': 1091},
#  {'team': 'Johnson C Smith', 'elo': 1091},
#  {'team': 'Houston Baptist', 'elo': 1091},
#  {'team': 'Kentucky Wesleyan', 'elo': 1086},
#  {'team': 'Utah Tech', 'elo': 1086},
#  {'team': 'Texas College', 'elo': 1085},
#  {'team': 'Clark Atlanta', 'elo': 1078},
#  {'team': 'Edward Waters', 'elo': 1078},
#  {'team': 'Livingstone', 'elo': 1076},
#  {'team': 'Adams State', 'elo': 1061},
#  {'team': 'WV Wesleyan', 'elo': 1061},
#  {'team': 'Western New Mexico', 'elo': 1060},
#  {'team': 'Lincoln (PA)', 'elo': 1060},
#  {'team': 'Central State', 'elo': 1040},
#  {'team': 'Fort Lewis', 'elo': 1031},
#  {'team': 'Mississippi Valley State', 'elo': 1028},
#  {'team': 'Texas Southern', 'elo': 1016},
#  {'team': 'Virginia Lynchburg', 'elo': 976}]

# %%
import matplotlib.pyplot as plt

# This is the styling I use. Check out other themes here: https://matplotlib.org/3.2.1/gallery/style_sheets/style_sheets_reference.html
plt.style.use('fivethirtyeight')

# Graph sizing
plt.rcParams["figure.figsize"] = [20,10]

# %%
def generate_chart(team):
    team_games = []
    for game in games:
        if game['home_team'] == team:
            team_games.append(dict(start_date=game['start_date'], elo=game['postgame_home_elo']))
        
        if game['away_team'] == team:
            team_games.append(dict(start_date=game['start_date'], elo=game['postgame_away_elo']))
            
    df = pd.DataFrame.from_records(team_games)
    
    fig, ax = plt.subplots()
    #plt.ylim([0, 2500])
    ax.plot(df.index, df['elo'])

    ax.set(xlabel='Game No.', ylabel='Elo Rating',
           title="Historical Elo Rating - {0}".format(team))
    
    plt.show()

# %%
generate_chart('Auburn')

# %%
generate_chart('Arizona State')
